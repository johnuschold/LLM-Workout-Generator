# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('musclewiki_exercises_with_type.csv')
data.head()
# Out:
#   Muscle Group          Exercise Name  \
# 0       biceps               Chin Ups
# 1       biceps    Cable Bayesian Curl
# 2       biceps          Dumbbell Curl
# 3       biceps   Dumbbell Hammer Curl
# 4       biceps  Dumbbell Reverse Curl
#
#                                         Instructions  \
# 0  1\nGrab the bar shoulder width apart with a su...
# 1  1\nUse a handle attachment. The cable should b...
# 2  1\nStand up straight with a dumbbell in each h...
# 3  1\nHold the dumbbells with a neutral grip (thu...
# 4  1\nGrab the dumbbells with a pronated (overhan...
#
#                                         Exercise URL  \
# 0  https://musclewiki.com/bodyweight/male/biceps/...
# 1  https://musclewiki.com/cables/male/biceps/cabl...
# 2  https://musclewiki.com/dumbbells/male/biceps/d...
# 3  https://musclewiki.com/dumbbells/male/biceps/d...
# 4  https://musclewiki.com/dumbbells/male/biceps/d...
#
#                                            Video URL  \
# 0  https://media.musclewiki.com/media/uploads/vid...
# 1  https://media.musclewiki.com/media/uploads/vid...
# 2  https://media.musclewiki.com/media/uploads/vid...
# 3  https://media.musclewiki.com/media/uploads/vid...
# 4  https://media.musclewiki.com/media/uploads/vid...
#
#                                      Detailed How-To    Difficulty  \
# 0  How To Perform The Chin Up\n\nSetup\n\nGrab th...  Intermediate
# 1                                                NaN      Beginner
# 2  How To Perform the Dumbbell Bicep Curl\n\nSetu...        Novice
# 3                                                NaN        Novice
# 4                                                NaN        Novice
#
#                                                 Tags    Exercise Type
# 0  How To Do A Chin Ups, intermediate Bodyweight ...  Muscle Building
# 1      Biceps Exercise, Bicep Exercise, Arm Exercise  Muscle Building
# 2  Biceps Exercise, beginner Dumbbells exercise, ...  Muscle Building
# 3  Biceps Exercise, beginner Dumbbells exercise, ...  Muscle Building
# 4  How to do Dumbbell Reverse Curl, How To Do A D...  Muscle Building

# %% [markdown]
# #MISSING Values

# %%
data.isna().sum()
# Out:
# Muscle Group          0
# Exercise Name         0
# Instructions         28
# Exercise URL          0
# Video URL            34
# Detailed How-To    2486
# Difficulty           19
# Tags                 49
# Exercise Type         0
# dtype: int64

# %%
missing_data_df = data[data['Instructions'].isna() | data['Difficulty'].isna()]
# Out:
# CSV file 'exercises_missing_instructions_or_difficulty.csv' created successfully.

# %%
output_filename = 'musclewiki_exercises_combined_with_filled_data.csv'
data_fixed = pd.read_csv('updated_exercises_with_instructions_and_difficulty.csv')

df_merged = pd.merge(
    data,
    data_fixed[['Exercise Name', 'Instructions', 'Difficulty']],
    on='Exercise Name',
    how='left',
    suffixes=('', '_updates') # Use empty string for left df to keep original names, and _updates for right df
)

# Fill missing values in the original 'Instructions' column using values from 'Instructions_updates'.
df_merged['Instructions'] = df_merged['Instructions'].fillna(df_merged['Instructions_updates'])

# Fill missing values in the original 'Difficulty' column using values from 'Difficulty_updates'.
df_merged['Difficulty'] = df_merged['Difficulty'].fillna(df_merged['Difficulty_updates'])

# Drop the temporary '_updates' columns which are no longer needed after filling.
df_merged = df_merged.drop(columns=['Instructions_updates', 'Difficulty_updates'])

# Drop any columns that originally ended with '_filled' from the DataFrame.
columns_to_drop_filled = [col for col in df_merged.columns if col.endswith('_filled')]
df_final = df_merged.drop(columns=columns_to_drop_filled)
# Out:
# Combined and cleaned data saved to final_combined_exercises_revised.csv

# %%
df_final.isna().sum()
# Out:
# Muscle Group          0
# Exercise Name         0
# Instructions          0
# Exercise URL          0
# Video URL            46
# Detailed How-To    2504
# Difficulty            0
# Tags                 61
# Exercise Type         0
# dtype: int64

# %%
placeholder_url = 'https://placehold.co/640x360/png?text=No+Video+Available'
df_final['Video URL'] = df_final['Video URL'].fillna(placeholder_url)

# %%
df_final.isna().sum()
# Out:
# Muscle Group          0
# Exercise Name         0
# Instructions          0
# Exercise URL          0
# Video URL             0
# Detailed How-To    2504
# Difficulty            0
# Tags                 61
# Exercise Type         0
# dtype: int64

# %%
# Ensure the required columns exist
required_columns = ['Instructions', 'Detailed How-To', 'Tags']

# Fill any potential NaN values with empty strings to avoid concatenation errors
df_final['Instructions'] = df_final['Instructions'].fillna('')
df_final['Detailed How-To'] = df_final['Detailed How-To'].fillna('')
df_final['Tags'] = df_final['Tags'].fillna('')

# Combine the columns into a new 'Combined_Text' column
# We'll separate them with a clear delimiter like "\n\n" for readability
df_final['Combined_Text'] = df_final['Instructions'] + "\n\n" + df_final['Detailed How-To'] + "\n\n" + df_final['Tags']

df_fin = df_final

# %%
df_fin.drop(columns=['Instructions', 'Detailed How-To', 'Tags'], inplace=True)
df_fin.head()
# Out:
#   Muscle Group          Exercise Name  \
# 0       biceps               Chin Ups
# 1       biceps    Cable Bayesian Curl
# 2       biceps          Dumbbell Curl
# 3       biceps   Dumbbell Hammer Curl
# 4       biceps  Dumbbell Reverse Curl
#
#                                         Exercise URL  \
# 0  https://musclewiki.com/bodyweight/male/biceps/...
# 1  https://musclewiki.com/cables/male/biceps/cabl...
# 2  https://musclewiki.com/dumbbells/male/biceps/d...
# 3  https://musclewiki.com/dumbbells/male/biceps/d...
# 4  https://musclewiki.com/dumbbells/male/biceps/d...
#
#                                            Video URL    Difficulty  \
# 0  https://media.musclewiki.com/media/uploads/vid...  Intermediate
# 1  https://media.musclewiki.com/media/uploads/vid...      Beginner
# 2  https://media.musclewiki.com/media/uploads/vid...        Novice
# 3  https://media.musclewiki.com/media/uploads/vid...        Novice
# 4  https://media.musclewiki.com/media/uploads/vid...        Novice
#
#      Exercise Type                                      Combined_Text
# 0  Muscle Building  1\nGrab the bar shoulder width apart with a su...
# 1  Muscle Building  1\nUse a handle attachment. The cable should b...
# 2  Muscle Building  1\nStand up straight with a dumbbell in each h...
# 3  Muscle Building  1\nHold the dumbbells with a neutral grip (thu...
# 4  Muscle Building  1\nGrab the dumbbells with a pronated (overhan...

# %%
df_fin.isna().sum()
# Out:
# Muscle Group     0
# Exercise Name    0
# Exercise URL     0
# Video URL        0
# Difficulty       0
# Exercise Type    0
# Combined_Text    0
# dtype: int64

# %%
# Extract the equipment type from the URL and create the new 'Equipment' column
df_fin['Equipment'] = df_fin['Exercise URL'].str.split('/').str[3]
df_fin.head()
# Out:
#   Muscle Group          Exercise Name  \
# 0       biceps               Chin Ups
# 1       biceps    Cable Bayesian Curl
# 2       biceps          Dumbbell Curl
# 3       biceps   Dumbbell Hammer Curl
# 4       biceps  Dumbbell Reverse Curl
#
#                                         Exercise URL  \
# 0  https://musclewiki.com/bodyweight/male/biceps/...
# 1  https://musclewiki.com/cables/male/biceps/cabl...
# 2  https://musclewiki.com/dumbbells/male/biceps/d...
# 3  https://musclewiki.com/dumbbells/male/biceps/d...
# 4  https://musclewiki.com/dumbbells/male/biceps/d...
#
#                                            Video URL    Difficulty  \
# 0  https://media.musclewiki.com/media/uploads/vid...  Intermediate
# 1  https://media.musclewiki.com/media/uploads/vid...      Beginner
# 2  https://media.musclewiki.com/media/uploads/vid...        Novice
# 3  https://media.musclewiki.com/media/uploads/vid...        Novice
# 4  https://media.musclewiki.com/media/uploads/vid...        Novice
#
#      Exercise Type                                      Combined_Text  \
# 0  Muscle Building  1\nGrab the bar shoulder width apart with a su...
# 1  Muscle Building  1\nUse a handle attachment. The cable should b...
# 2  Muscle Building  1\nStand up straight with a dumbbell in each h...
# 3  Muscle Building  1\nHold the dumbbells with a neutral grip (thu...
# 4  Muscle Building  1\nGrab the dumbbells with a pronated (overhan...
#
#     Equipment
# 0  bodyweight
# 1      cables
# 2   dumbbells
# 3   dumbbells
# 4   dumbbells

# %%
print(df_fin['Equipment'].unique())
# Out:
# ['bodyweight' 'cables' 'dumbbells' 'barbell' 'kettlebells' 'machine'
#  'stretches' 'band' 'plate' 'trx' 'smith-machine' 'yoga' 'bosu-ball'
#  'vitruvian' 'cardio' 'recovery' 'medicine-ball']

# %%
equipment_to_empty = ['recovery', 'cardio', 'stretches', 'yoga']

# Set the 'Equipment' cell to NaN for rows where 'Equipment' is in the list
df_fin.loc[df_fin['Equipment'].isin(equipment_to_empty), 'Equipment'] = np.nan

# %%
print(df_fin['Equipment'].unique())
# Out:
# ['bodyweight' 'cables' 'dumbbells' 'barbell' 'kettlebells' 'machine' nan
#  'band' 'plate' 'trx' 'smith-machine' 'bosu-ball' 'vitruvian'
#  'medicine-ball']

# %%
df_fin.describe()
# Out:
#        Muscle Group                       Exercise Name  \
# count          2607                                2607
# unique           36                                1474
# top          glutes  Kettlebell Single Arm Curtsy Lunge
# freq            491                                  16
#
#                                              Exercise URL  \
# count                                                2607
# unique                                               1474
# top     https://musclewiki.com/kettlebells/male/glutes...
# freq                                                   16
#
#                                                 Video URL Difficulty  \
# count                                                2607       2607
# unique                                               1460          4
# top     https://placehold.co/640x360/png?text=No+Video...   Beginner
# freq                                                   46        887
#
#           Exercise Type                                      Combined_Text  \
# count              2607                                               2607
# unique                3                                               1466
# top     Muscle Building  1\nStand upright with your feet hip-width apar...
# freq               2258                                                 16
#
#         Equipment
# count        2142
# unique         13
# top     dumbbells
# freq          410

# %%
df_fin.head()
# Out:
#   Muscle Group          Exercise Name  \
# 0       biceps               Chin Ups
# 1       biceps    Cable Bayesian Curl
# 2       biceps          Dumbbell Curl
# 3       biceps   Dumbbell Hammer Curl
# 4       biceps  Dumbbell Reverse Curl
#
#                                         Exercise URL  \
# 0  https://musclewiki.com/bodyweight/male/biceps/...
# 1  https://musclewiki.com/cables/male/biceps/cabl...
# 2  https://musclewiki.com/dumbbells/male/biceps/d...
# 3  https://musclewiki.com/dumbbells/male/biceps/d...
# 4  https://musclewiki.com/dumbbells/male/biceps/d...
#
#                                            Video URL    Difficulty  \
# 0  https://media.musclewiki.com/media/uploads/vid...  Intermediate
# 1  https://media.musclewiki.com/media/uploads/vid...      Beginner
# 2  https://media.musclewiki.com/media/uploads/vid...        Novice
# 3  https://media.musclewiki.com/media/uploads/vid...        Novice
# 4  https://media.musclewiki.com/media/uploads/vid...        Novice
#
#      Exercise Type                                      Combined_Text  \
# 0  Muscle Building  1\nGrab the bar shoulder width apart with a su...
# 1  Muscle Building  1\nUse a handle attachment. The cable should b...
# 2  Muscle Building  1\nStand up straight with a dumbbell in each h...
# 3  Muscle Building  1\nHold the dumbbells with a neutral grip (thu...
# 4  Muscle Building  1\nGrab the dumbbells with a pronated (overhan...
#
#     Equipment
# 0  bodyweight
# 1      cables
# 2   dumbbells
# 3   dumbbells
# 4   dumbbells

# %%
# Group by 'Exercise Name' and aggregate 'Muscle Group' and 'Equipment'
# into lists of unique values, then convert to comma-separated strings.
df_combined = df_fin.groupby('Exercise Name').agg(
    Muscle_Group=('Muscle Group', lambda x: ', '.join(x.dropna().unique())),
    Exercise_URL=('Exercise URL', 'first'),
    Video_URL=('Video URL', 'first'),
    Difficulty=('Difficulty', 'first'),
    Exercise_Type=('Exercise Type', 'first'),
    Combined_Text=('Combined_Text', 'first'),
    Equipment=('Equipment', lambda x: ', '.join(x.dropna().unique()))
).reset_index()
# Reorder columns to ensure 'Exercise Name' is first and other columns are in a logical order
# Rename the aggregated columns to their original names if desired,
# or keep them as Muscle_Group and Equipment
df_combined.rename(columns={'Muscle_Group': 'Muscle Group'}, inplace=True)


# Reorder columns to ensure 'Exercise Name' is first and other columns are in a logical order
column_order = [
    'Exercise Name',
    'Muscle Group',
    'Equipment',
    'Difficulty',
    'Exercise_Type',
    'Combined_Text',
    'Exercise_URL',
    'Video_URL'
]
df_final_unique = df_combined[column_order]

df_final_unique.head()
# Out:
#                         Exercise Name            Muscle Group Equipment  \
# 0   Abdominals Stretch Variation Four              abdominals
# 1    Abdominals Stretch Variation One              abdominals
# 2  Abdominals Stretch Variation Three    abdominals, obliques
# 3    Abdominals Stretch Variation Two    abdominals, obliques
# 4       Abductor Leg Raise Side Lying  glutes, gluteus-medius
#
#   Difficulty    Exercise_Type  \
# 0   Beginner       Stretching
# 1     Novice       Stretching
# 2     Novice       Stretching
# 3     Novice       Stretching
# 4   Beginner  Muscle Building
#
#                                        Combined_Text  \
# 0  1\nLay on a ball or a Bosu ball with your feet...
# 1  1\nLay on your stomach on the floor with your ...
# 2  1\nStand upright.\n2\nAfter completing the des...
# 3  1\nStand upright.\n2\nReach with both hands up...
# 4  1\nStabilise yourself in the side lying positi...
#
#                                         Exercise_URL  \
# 0  https://musclewiki.com/stretches/male/abdomina...
# 1  https://musclewiki.com/stretches/male/abdomina...
# 2  https://musclewiki.com/stretches/male/abdomina...
# 3  https://musclewiki.com/stretches/male/abdomina...
# 4  https://musclewiki.com/recovery/male/glutes/ab...
#
#                                            Video_URL
# 0  https://media.musclewiki.com/media/uploads/vid...
# 1  https://media.musclewiki.com/media/uploads/vid...
# 2  https://media.musclewiki.com/media/uploads/vid...
# 3  https://media.musclewiki.com/media/uploads/vid...
# 4  https://media.musclewiki.com/media/uploads/vid...

# %%
display(df_final_unique[df_final_unique['Exercise Name']=='Kettlebell Single Arm Curtsy Lunge'])
# Out:
#                           Exercise Name  \
# 925  Kettlebell Single Arm Curtsy Lunge
#
#                                        Muscle Group    Equipment  \
# 925  quads, glutes, gluteus-medius, gluteus-maximus  kettlebells
#
#        Difficulty    Exercise_Type  \
# 925  Intermediate  Muscle Building
#
#                                          Combined_Text  \
# 925  1\nStand upright with your feet hip-width apar...
#
#                                           Exercise_URL  \
# 925  https://musclewiki.com/kettlebells/male/glutes...
#
#                                              Video_URL
# 925  https://placehold.co/640x360/png?text=No+Video...

# %%
df_final_unique.describe()
# Out:
#                             Exercise Name   Muscle Group Equipment Difficulty  \
# count                                1474           1474      1474       1474
# unique                               1474            142        14          4
# top     Abdominals Stretch Variation Four  quads, glutes             Beginner
# freq                                    1            182       306        553
#
#           Exercise_Type                                      Combined_Text  \
# count              1474                                               1474
# unique                3                                               1450
# top     Muscle Building  1\nAdjust weight for assistance. Stand on plat...
# freq               1252                                                  4
#
#                                              Exercise_URL  \
# count                                                1474
# unique                                               1474
# top     https://musclewiki.com/stretches/male/abdomina...
# freq                                                    1
#
#                                                 Video_URL
# count                                                1474
# unique                                               1455
# top     https://placehold.co/640x360/png?text=No+Video...
# freq                                                   13

# %%
df_temp = df_final_unique[df_final_unique['Equipment']=='']

# %%
df_temp.head()
# Out:
#                         Exercise Name            Muscle Group Equipment  \
# 0   Abdominals Stretch Variation Four              abdominals
# 1    Abdominals Stretch Variation One              abdominals
# 2  Abdominals Stretch Variation Three    abdominals, obliques
# 3    Abdominals Stretch Variation Two    abdominals, obliques
# 4       Abductor Leg Raise Side Lying  glutes, gluteus-medius
#
#   Difficulty    Exercise_Type  \
# 0   Beginner       Stretching
# 1     Novice       Stretching
# 2     Novice       Stretching
# 3     Novice       Stretching
# 4   Beginner  Muscle Building
#
#                                        Combined_Text  \
# 0  1\nLay on a ball or a Bosu ball with your feet...
# 1  1\nLay on your stomach on the floor with your ...
# 2  1\nStand upright.\n2\nAfter completing the des...
# 3  1\nStand upright.\n2\nReach with both hands up...
# 4  1\nStabilise yourself in the side lying positi...
#
#                                         Exercise_URL  \
# 0  https://musclewiki.com/stretches/male/abdomina...
# 1  https://musclewiki.com/stretches/male/abdomina...
# 2  https://musclewiki.com/stretches/male/abdomina...
# 3  https://musclewiki.com/stretches/male/abdomina...
# 4  https://musclewiki.com/recovery/male/glutes/ab...
#
#                                            Video_URL
# 0  https://media.musclewiki.com/media/uploads/vid...
# 1  https://media.musclewiki.com/media/uploads/vid...
# 2  https://media.musclewiki.com/media/uploads/vid...
# 3  https://media.musclewiki.com/media/uploads/vid...
# 4  https://media.musclewiki.com/media/uploads/vid...

# %%
df_with_equipment = pd.read_csv('exercise_with_equipment_fixed.csv')
df_with_equipment.describe()
# Out:
#                             Exercise Name Muscle Group Equipment Difficulty  \
# count                                 306          306       306        306
# unique                                306           59         7          4
# top     Abdominals Stretch Variation Four       calves   unknown   Beginner
# freq                                    1           27       240        187
#
#        Exercise_Type                                      Combined_Text  \
# count            306                                                306
# unique             3                                                301
# top       Stretching  1\nKneel in front of a bench, placing your elb...
# freq             151                                                  3
#
#                                              Exercise_URL  \
# count                                                 306
# unique                                                306
# top     https://musclewiki.com/stretches/male/abdomina...
# freq                                                    1
#
#                                                 Video_URL
# count                                                 306
# unique                                                304
# top     https://placehold.co/640x360/png?text=No+Video...
# freq                                                    3

# %%
df_no_equipment = df_final_unique


df_mergedd = df_no_equipment.merge(
    df_with_equipment[['Exercise Name', 'Equipment']],
    on='Exercise Name',
    how='left',
    suffixes=('', '_new')
)

df_mergedd['Equipment'].replace('', np.nan, inplace=True)

# Now fill NaNs with values from 'Equipment_new'
df_mergedd['Equipment'] = df_mergedd['Equipment'].fillna(df_mergedd['Equipment_new'])

# Drop the temporary column
df_mergedd.drop(columns=['Equipment_new'], inplace=True)

# Save the updated DataFrame to a new CSV file
#df_merged.to_csv('exercise_no_equip_updated.csv', index=False)
#df_final.to_csv(output_filename, index=False)

#print(f"Combined and cleaned data saved to {output_filename}")

# %%
df_mergedd.describe()
# Out:
#                             Exercise Name   Muscle Group Equipment Difficulty  \
# count                                1474           1474      1474       1474
# unique                               1474            142        14          4
# top     Abdominals Stretch Variation Four  quads, glutes   unknown   Beginner
# freq                                    1            182       240        553
#
#           Exercise_Type                                      Combined_Text  \
# count              1474                                               1474
# unique                3                                               1450
# top     Muscle Building  1\nAdjust weight for assistance. Stand on plat...
# freq               1252                                                  4
#
#                                              Exercise_URL  \
# count                                                1474
# unique                                               1474
# top     https://musclewiki.com/stretches/male/abdomina...
# freq                                                    1
#
#                                                 Video_URL
# count                                                1474
# unique                                               1455
# top     https://placehold.co/640x360/png?text=No+Video...
# freq                                                   13

# %%
df_mergedd['Equipment'] = df_mergedd['Equipment'].replace('unknown','None')
df_mergedd['Difficulty'] = df_mergedd['Difficulty'].replace('Novice','Beginner')
df_mergedd.describe()
# Out:
#                             Exercise Name   Muscle Group Equipment Difficulty  \
# count                                1474           1474      1474       1474
# unique                               1474            142        14          3
# top     Abdominals Stretch Variation Four  quads, glutes      None   Beginner
# freq                                    1            182       240        922
#
#           Exercise_Type                                      Combined_Text  \
# count              1474                                               1474
# unique                3                                               1450
# top     Muscle Building  1\nAdjust weight for assistance. Stand on plat...
# freq               1252                                                  4
#
#                                              Exercise_URL  \
# count                                                1474
# unique                                               1474
# top     https://musclewiki.com/stretches/male/abdomina...
# freq                                                    1
#
#                                                 Video_URL
# count                                                1474
# unique                                               1455
# top     https://placehold.co/640x360/png?text=No+Video...
# freq                                                   13

# %%
# Load the dataset
df = df_mergedd

# Add a unique 'id' column. You can use the DataFrame's index or a sequential counter.
df['id'] = df.index # or use range(len(df)) for a simple sequential ID

# Create the 'description' column including 'Difficulty' and 'Combined_Text'
df['description'] = df.apply(lambda row: f"The '{row['Exercise Name']}' is a '{row['Difficulty']}' level '{row['Exercise_Type']}' exercise that targets the '{row['Muscle Group']}' and requires '{row['Equipment']}'. Instructions and tips: {row['Combined_Text']}", axis=1)

# Reorder columns to have 'id' at the beginning (optional, for better readability)
df = df[['id', 'Exercise Name', 'Muscle Group', 'Equipment', 'Difficulty', 'Exercise_Type', 'Combined_Text', 'Exercise_URL', 'Video_URL', 'description']]

# %%
df['description'] = df['description'].str.replace(r'[\n\r]+', '.', regex=True)

# %%
df['description'].head()
# Out:
# 0    The 'Abdominals Stretch Variation Four' is a '...
# 1    The 'Abdominals Stretch Variation One' is a 'B...
# 2    The 'Abdominals Stretch Variation Three' is a ...
# 3    The 'Abdominals Stretch Variation Two' is a 'B...
# 4    The 'Abductor Leg Raise Side Lying' is a 'Begi...
# Name: description, dtype: object

# %%
output_filename_fin = 'exercises_data_final.csv'
df.to_csv(output_filename_fin, index=False)
